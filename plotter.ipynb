# %%
import sys, subprocess
from matplotlib import pyplot as plt

sizes=[]
accuracy=[]
x_values=list(range(1,101))
for i in x_values:
    result=subprocess.check_output(['python3', 'compression.py', str(i)]).decode('utf-8').split()
    sizes.append(int(result[0]))
    accuracy.append(float(result[1]))

# %%
figure, ax=plt.subplots()
ax.plot(x_values, accuracy)
ax2=ax.twinx()
ax2.plot(x_values, sizes)
plt.show()

# %%
figure, ax=plt.subplots()
ax.plot(x_values, accuracy)
ax2=ax.twinx()
ax2.plot(x_values, sizes)
plt.show()

# %%
print(sizes)
# Out:
# [153575, 113937, 93455, 79643, 68362, 59449, 53078, 48193, 44493, 41312, 38806, 36955, 35205, 33785, 32519, 31320, 30140, 28994, 28133, 27226, 26462, 25568, 24943, 24328, 23750, 23211, 22756, 22355, 21944, 21628, 21211, 20892, 20423, 20174, 19822, 19575, 19226, 18997, 18728, 18549, 18342, 18091, 17829, 17564, 17326, 17123, 16968, 16719, 16616, 16398, 16081, 15881, 15674, 15530, 15364, 15161, 15049, 14792, 14709, 14510, 14339, 14291, 14137, 13979, 13727, 13647, 13514, 13391, 13350, 13190, 13097, 12919, 12845, 12800, 12674, 12600, 12433, 12384, 12321, 12190, 12045, 12005, 11937, 11784, 11691, 11661, 11512, 11357, 11273, 11174, 11037, 10959, 10925, 10869, 10783, 10736, 10672, 10634, 10582, 10488]

# %%
print(accuracy)
# Out:
# [0.12147997883118829, 0.23080108223116858, 0.3328683514593796, 0.4211504585140769, 0.5002460216806868, 0.56488016780418, 0.6249494504822289, 0.6734979529755356, 0.7224086071992065, 0.7669358448778951, 0.8138197250342325, 0.8507989647055956, 0.8933181013477286, 0.9355937214544833, 0.9761958192186658, 1.0285003120469787, 1.0566042342647064, 1.1007738811693877, 1.1367248263473761, 1.1651262778386298, 1.1991261294763753, 1.2398496991154917, 1.2764483717170017, 1.3075829911038717, 1.3483207413683145, 1.380803831265321, 1.420505569404987, 1.4365983812307914, 1.4735130987622571, 1.4970623970168717, 1.5343342504747788, 1.5593317469595398, 1.599634393259178, 1.6225840732406989, 1.652304099091594, 1.694400979246594, 1.7125485057341148, 1.7495939383807104, 1.7737996958121371, 1.7941878980101176, 1.839043715518098, 1.8882021210669901, 1.9149762588149615, 1.9390228046153999, 1.9610543455661342, 1.9963497841898594, 2.036928622777905, 2.0857886450520486, 2.094904889217546, 2.1228163941575255, 2.136
# ...

# %%
print(sizes[39], accuracy[39])
# Out:
# 22762 1.4814720681676201
